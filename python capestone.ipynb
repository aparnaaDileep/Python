# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\APARNA DILEEP\Downloads\myexcel - myexcel.csv.csv")

# %%
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)

# %%
data["Height"] = np.random.randint(150, 181, size=len(data))

# %%
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     159     235
# 2     John Holland  Boston Celtics      30       SG   27     180     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     158     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     162     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     172     256
# 456    Jeff Withey       Utah Jazz      24        C   26     179     231
# 457       Priyanka       Utah Jazz      34        C   25     157     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  165.041485  221.543668  4.833970e+06
# std     15.966837    4.400128    8.824103   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  172.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height        int32
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
#  Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
employee=data['Team'].value_counts()

# %%
employee
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
percent=(employee/len(data))*100
percent
# Out:
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# Philadelphia 76ers        3.275109
# ...

# %%
plt.figure(figsize=(8, 8))
plt.pie(employee, labels=employee.index, autopct='%1.1f%%')
plt.title("Employee Distribution by Team", fontsize=14)
plt.show()

# %% [markdown]
# Segregate employees based on their positions within the company.

# %%
based_on_position=data.groupby('Position')['Name'].count()

# %%
based_on_position
# Out:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102
# Name: Name, dtype: int64

# %%
maxi=data['Age'].max()
mini=data['Age'].min()
print(maxi,'and',mini)
# Out:
# 40 and 19

# %%
bins = [15, 25, 35, 45]  
labels = ["15-25", "25-35", "35-45"]
data["Age_group"] = pd.cut(data["Age"], bins=bins, labels=labels, right=True)
distribution = data["Age_group"].value_counts()

# %%
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     159     235
# 2     John Holland  Boston Celtics      30       SG   27     180     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     158     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     162     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     172     256
# 456    Jeff Withey       Utah Jazz      24        C   26     179     231
# 457       Priyanka       Utah Jazz      34        C   25     157     231
#
#                College     Salary Age_group
# 0                Texas  7730337.0     15-25
# ...

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=distribution.index, y=distribution.values)
plt.title("Employee Count by Position", fontsize=14)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Employee Count", fontsize=12)
plt.show()

# %% [markdown]
# Identify the predominant age group among employees.

# %%
distribution.plot(kind='bar', title="Age Group Distribution")
# Out:
# <AxesSubplot:title={'center':'Age Group Distribution'}>

# %% [markdown]
#  Discover which team and position have the highest salary expenditure.

# %%
team_salary_expenditure = data.groupby("Team")["Salary"].sum()
position_salary_expenditure = data.groupby("Position")["Salary"].sum()

# %%
highest_team = team_salary_expenditure.idxmax()
highest_position = position_salary_expenditure.idxmax()

# %%
print("The team that has highest salary expenditure is ",highest_team)
print("The position that has highest salary expenditure is ", highest_position)
# Out:
# The team that has highest salary expenditure is  Cleveland Cavaliers
# The position that has highest salary expenditure is  C

# %%
plt.figure(figsize=(8, 6))
team_salary_expenditure.sort_values().plot(kind='bar', color="skyblue", edgecolor="black")
plt.title("Total Salary Expenditure by Team", fontsize=14)
plt.xlabel("Total Salary ", fontsize=12)
plt.ylabel("Team", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
position_salary_expenditure.sort_values().plot(kind='bar', color="lightgreen", edgecolor="black")
plt.title("Total Salary Expenditure by Position", fontsize=14)
plt.xlabel("Total Salary (in $)", fontsize=12)
plt.ylabel("Position", fontsize=12)
plt.show()

# %% [markdown]
# Investigate if there's any correlation between age and salary, and represent it visually

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation = data["Age"].corr(data["Salary"])

plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x=data['Age'], y=data['Salary'], sizes=(50, 200))

plt.title("Correlation between age and salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
